# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepthi2006/Linear-Regression-on-Head-Brain-Dataset/blob/main/Simple_Linear_Regresion_on_head_brain_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
jemishdonda_headbrain_path = kagglehub.dataset_download('jemishdonda/headbrain')

print('Data source import complete.')
# Out:
# Using Colab cache for faster access to the 'headbrain' dataset.
# Data source import complete.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#Reading Data
data = pd.read_csv('/content/headbrain (1).csv')
print(data.shape)
data.head()
# Out:
# (237, 4)
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
data.describe()
# Out:
#            Gender   Age Range  Head Size(cm^3)  Brain Weight(grams)
# count  237.000000  237.000000       237.000000           237.000000
# mean     1.434599    1.535865      3633.991561          1282.873418
# std      0.496753    0.499768       365.261422           120.340446
# min      1.000000    1.000000      2720.000000           955.000000
# 25%      1.000000    1.000000      3389.000000          1207.000000
# 50%      1.000000    2.000000      3614.000000          1280.000000
# 75%      2.000000    2.000000      3876.000000          1350.000000
# max      2.000000    2.000000      4747.000000          1635.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Gender               237 non-null    int64
#  1   Age Range            237 non-null    int64
#  2   Head Size(cm^3)      237 non-null    int64
#  3   Brain Weight(grams)  237 non-null    int64
# dtypes: int64(4)
# memory usage: 7.5 KB

# %%
data.size
# Out:
# 948

# %%
data.shape
# Out:
# (237, 4)

# %%
X=data[['Head Size(cm^3)']]
y=data['Brain Weight(grams)']

# %%
X.head()
# Out:
#    Head Size(cm^3)
# 0             4512
# 1             3738
# 2             4261
# 3             3777
# 4             4177

# %%
y.head()
# Out:
# 0    1530
# 1    1297
# 2    1335
# 3    1282
# 4    1590
# Name: Brain Weight(grams), dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y)

# %%
from sklearn.linear_model import LinearRegression

l = LinearRegression()
l.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = l.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np

r2 = r2_score(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("R2 Score:", r2)
print("RMSE:", rmse)
# Out:
# R2 Score: 0.651985293344701
# RMSE: 61.14944046690903

# %%
print("Coefficient:", l.coef_)
print("Intercept:", l.intercept_)
# Out:
# Coefficient: [0.26477732]
# Intercept: 323.1845038452983

# %%
plt.figure()
plt.scatter(X_test, y_test, label="Actual")
plt.plot(X_test, y_pred, color="red", label="Regression Line")
plt.xlabel(X.columns[0])
plt.ylabel("Revenue")
plt.legend()
plt.show()
